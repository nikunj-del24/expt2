# %%
Nikunj Deep Upadhyay
25070123081
entc b1

# %%
list3=["apple","orange","apple","cherry"]
print(list3)
# Out:
# ['apple', 'orange', 'apple', 'cherry']

# %%
list4=["apple","banana","orange","cherry","mango","kiwi"]
print(list4[2:5])
print(list4[2])
print(list4[-4])
print(list4[:4])
print(list4[2:])
# Out:
# ['orange', 'cherry', 'mango']
# orange
# orange
# ['apple', 'banana', 'orange', 'cherry']
# ['orange', 'cherry', 'mango', 'kiwi']

# %%
list5=["apple","orange","mango"]
list5[1]=2
print(list5)
# Out:
# ['apple', 2, 'mango']

# %%
list6=["apple","orange","cherry"]
list6.append("mango")
print(list6)
# Out:
# ['apple', 'orange', 'cherry', 'mango']

# %%
list7=["apple","banana","orange"]
list7.insert(1,"mango")
print(list7)
# Out:
# ['apple', 'mango', 'banana', 'orange']

# %%
list8=["apple","banana","orange"]
list9=["kiwi","mango"]
list8.extend(list9)
print(list8)
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'mango']

# %%
list10=[90,82,66,76,33]
print(max(list10))
print(min(list10))
print(sum(list10))
print(len(list10))
print(sum(list10)/len(list10))
print(sorted(list10))
# Out:
# 90
# 33
# 347
# 5
# 69.4
# [33, 66, 76, 82, 90]

# %%
grocery=["soap","shampoo","oil","conditioner","salt"]
grocery.append("cornflakes")
print(grocery)
grocery.remove(grocery[0])
print(grocery)
grocery.remove(grocery[0])
print(grocery)
# Out:
# ['soap', 'shampoo', 'oil', 'conditioner', 'salt', 'cornflakes']
# ['shampoo', 'oil', 'conditioner', 'salt', 'cornflakes']
# ['oil', 'conditioner', 'salt', 'cornflakes']
